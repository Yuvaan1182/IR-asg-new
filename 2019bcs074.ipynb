# %%
# importing all modules
import pandas as pd
import math
import random
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from keras import models
from keras import layers
from keras import regularizers
import numpy as np

# %%
l1 = l2 = l3 = 7 # length

# %%
def three_link_manipulator_dataset():
    rows = []
    for i in range(1, 100000):
        theta1 = round(random.uniform(0, math.pi), 2)
        theta2 = round(random.uniform(-math.pi, 0), 2)
        theta3 = round(random.uniform(-math.pi/2, math.pi/2), 2)
        
        x = round(l1*math.cos(theta1)+l2*math.cos(theta1+theta2)+l3*math.cos(theta1+theta2+theta3), 2)
        y = round(l1*math.sin(theta1)+l2*math.sin(theta1+theta2)+l3*math.sin(theta1+theta2+theta3), 2)
        phi = round(math.degrees(theta1)+math.degrees(theta2)+math.degrees(theta3), 2)
        
        rows.append([theta1, theta2, theta3, x, y, phi])

    df = pd.DataFrame(rows, columns=['theta1', 'theta2', 'theta3', 'x', 'y', 'phi'])
    df.to_csv('three_link.csv', index=False)
    
three_link_manipulator_dataset()

# %%
three_link_data = pd.read_csv('three_link.csv')
three_link_data.head()

# %%
plt.scatter(three_link_data['x'], three_link_data['y'])
plt.show()

# %%
# Splitting training and testing dataset
X = three_link_data[['x', 'y', 'phi']]
y = three_link_data[['theta1', 'theta2', 'theta3']]
train_X, test_X, train_y, test_y = train_test_split(X, y, test_size=0.1)

# %%
# Defining model

model = models.Sequential()
model.add(layers.Dense(units=3, input_dim=3, kernel_initializer='uniform'))
model.add(layers.Dense(units=100, kernel_initializer='uniform', activation='relu'))
model.add(layers.Dense(units=100, kernel_initializer='uniform', activation='relu'))
model.add(layers.Dense(units=3, kernel_initializer = 'uniform', activation='linear'))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 3)                 12
# _________________________________________________________________
# dense_5 (Dense)              (None, 100)               400
# _________________________________________________________________
# dense_6 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_7 (Dense)              (None, 3)                 303
# =================================================================
# Total params: 10,815
# Trainable params: 10,815
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['accuracy'])

# %%
# training model
history = model.fit(train_X, train_y, epochs=30, validation_split=0.1, shuffle=True)
# Out:
# Epoch 1/30
# 2532/2532 [==============================] - 4s 2ms/step - loss: 0.4176 - accuracy: 0.9044 - val_loss: 0.0564 - val_accuracy: 0.9327
# Epoch 2/30
# 2532/2532 [==============================] - 4s 2ms/step - loss: 0.0430 - accuracy: 0.9573 - val_loss: 0.0326 - val_accuracy: 0.9543
# Epoch 3/30
# 2532/2532 [==============================] - 4s 2ms/step - loss: 0.0316 - accuracy: 0.9655 - val_loss: 0.0265 - val_accuracy: 0.9707
# Epoch 4/30
# 2532/2532 [==============================] - 4s 2ms/step - loss: 0.0261 - accuracy: 0.9716 - val_loss: 0.0228 - val_accuracy: 0.9696
# Epoch 5/30
# 2532/2532 [==============================] - 4s 2ms/step - loss: 0.0229 - accuracy: 0.9744 - val_loss: 0.0169 - val_accuracy: 0.9761
# Epoch 6/30
# 2532/2532 [==============================] - 4s 2ms/step - loss: 0.0202 - accuracy: 0.9756 - val_loss: 0.0193 - val_accuracy: 0.9754
# Epoch 7/30
# 2532/2532 [==============================] - 4s 2ms/step - loss: 0.0191 - accuracy: 0.9768 - val_loss: 0.0158 - val_accuracy: 0.9778
# Epoch 8/30
# 2532/2532 [==============================] - 4s 2ms/step - loss: 0.0175 - accuracy: 0.9784 - val_loss: 0.0132 - val_accuracy: 0.9769
# Epoch 9/30
# 2532/2532 [==============================] - 4s 2ms/step - loss: 0.0174 - accuracy: 0.9783 - val_loss: 0.0149 - val_accuracy: 0.9789
# Epoch 10/30
# 2532/2532 [==============================] - 4s 2ms/step - loss: 0.0163 - accuracy: 0.9789 - val_loss: 0.0159 - val_accuracy: 0.9807
# Epoch 11/30
# 2532/2532 [==============================] - 4s 2ms/step - loss: 0.0162 - accuracy: 0.9793 - val_loss: 0.0181 - val_accuracy: 0.9757
# Epoch 12/30
# 2532/2532 [==============================] - 4s 2ms/step - loss: 0.0154 - accuracy: 0.9803 - val_loss: 0.0219 - val_accuracy: 0.9797
# Epoch 13/30
# 2532/2532 [==============================] - 4s 2ms/step - loss: 0.0155 - accuracy: 0.9781 - val_loss: 0.0115 - val_accuracy: 0.9822
# Epoch 14/30
# 2532/2532 [==============================] - 4s 2ms/step - loss: 0.0148 - accuracy: 0.9803 - val_loss: 0.0158 - val_accuracy: 0.9794
# Epoch 15/30
# 2532/2532 [==============================] - 4s 2ms/step - loss: 0.0137 - accuracy: 0.9799 - val_loss: 0.0274 - val_accuracy: 0.9688
# Epoch 16/30
# 2532/2532 [==============================] - 4s 2ms/step - loss: 0.0136 - accuracy: 0.9810 - val_loss: 0.0098 - val_accuracy: 0.9846
# Epoch 17/30
# 2532/2532 [==============================] - 4s 2ms/step - loss: 0.0134 - accuracy: 0.9811 - val_loss: 0.0139 - val_accuracy: 0.9828
# Epoch 18/30
# 2532/2532 [==============================] - 4s 2ms/step - loss: 0.0136 - accuracy: 0.9822 - val_loss: 0.0102 - val_accuracy: 0.9842
# Epoch 19/30
# 2532/2532 [==============================] - 4s 2ms/step - loss: 0.0126 - accuracy: 0.9825 - val_loss: 0.0207 - val_accuracy: 0.9717
# Epoch 20/30
# 2532/2532 [==============================] - 4s 2ms/step - loss: 0.0135 - accuracy: 0.9823 - val_loss: 0.0105 - val_accuracy: 0.9856
# Epoch 21/30
# 2532/2532 [==============================] - 4s 2ms/step - loss: 0.0122 - accuracy: 0.9835 - val_loss: 0.0114 - val_accuracy: 0.9869
# Epoch 22/30
# 2532/2532 [==============================] - 4s 2ms/step - loss: 0.0128 - accuracy: 0.9830 - val_loss: 0.0135 - val_accuracy: 0.9732
# Epoch 23/30
# 2532/2532 [==============================] - 4s 2ms/step - loss: 0.0121 - accuracy: 0.9834 - val_loss: 0.0090 - val_accuracy: 0.9873
# Epoch 24/30
# 2532/2532 [==============================] - 4s 2ms/step - loss: 0.0117 - accuracy: 0.9831 - val_loss: 0.0083 - val_accuracy: 0.9874
# Epoch 25/30
# 2532/2532 [==============================] - 4s 2ms/step - loss: 0.0113 - accuracy: 0.9831 - val_loss: 0.0097 - val_accuracy: 0.9813
# Epoch 26/30
# 2532/2532 [==============================] - 4s 2ms/step - loss: 0.0114 - accuracy: 0.9845 - val_loss: 0.0107 - val_accuracy: 0.9856
# Epoch 27/30
# 2532/2532 [==============================] - 4s 2ms/step - loss: 0.0115 - accuracy: 0.9835 - val_loss: 0.0097 - val_accuracy: 0.9832
# Epoch 28/30
# 2532/2532 [==============================] - 4s 2ms/step - loss: 0.0114 - accuracy: 0.9834 - val_loss: 0.0109 - val_accuracy: 0.9824
# Epoch 29/30
# 2532/2532 [==============================] - 4s 2ms/step - loss: 0.0113 - accuracy: 0.9843 - val_loss: 0.0172 - val_accuracy: 0.9833
# Epoch 30/30
# 2532/2532 [==============================] - 4s 2ms/step - loss: 0.0105 - accuracy: 0.9849 - val_loss: 0.0087 - val_accuracy: 0.9876

# %%
# Plotting model accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# Plotting model loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
# Evaluating the model on test set

test_loss, test_acc = model.evaluate(test_X, test_y)

print('\nTesting Loss = ', test_loss) 
print('Testing Accuracy = ', test_acc)
# Out:
# 313/313 [==============================] - 0s 950us/step - loss: 0.0086 - accuracy: 0.9886
#
# Testing Loss =  0.008639857172966003
# Testing Accuracy =  0.9886000156402588

# %%
def iiitm_dataset():
    rows = []
    # for I
    arr = np.linspace(5, 7, 100)
    for y in arr:
        x = 6
        theta = math.degrees(math.atan(y/x))
        rows.append([x, y, theta])

    # for I
    arr = np.linspace(5, 7, 100)
    for y in arr:
        x = 7
        theta = math.degrees(math.atan(y/x))
        rows.append([x, y, theta])

    # for I
    arr = np.linspace(5, 7, 100)
    for y in arr:
        x = 8
        theta = math.degrees(math.atan(y/x))
        rows.append([x, y, theta])

    # for T
    arr = np.linspace(9, 10, 100)
    for x in arr:
        y = 7
        theta = math.degrees(math.atan(y/x))
        rows.append([x, y, theta])

    arr = np.linspace(5, 7, 100)
    for y in arr:
        x = 9.5
        theta = math.degrees(math.atan(y/x))
        rows.append([x, y, theta])

    # for M
    arr = np.linspace(5, 7, 100)
    for y in arr:
        x = 11
        theta = math.degrees(math.atan(y/x))
        rows.append([x, y, theta])

    arr = np.linspace(5, 7, 100)
    for y in arr:
        x = ((-y)+29)/2
        theta = math.degrees(math.atan(y/x))
        rows.append([x, y, theta])

    arr = np.linspace(5, 7, 100)
    for y in arr:
        x = ((y)+19)/2
        theta = math.degrees(math.atan(y/x))
        rows.append([x, y, theta])

    arr = np.linspace(5, 7, 100)
    for y in arr:
        x = 13
        theta = math.degrees(math.atan(y/x))
        rows.append([x, y, theta])

    df = pd.DataFrame(rows, columns=['x', 'y', 'theta'])
    df.to_csv('iiitm.csv', index=False)
    
iiitm_dataset()

# %%
def three_link_forward_kinematics(theta1, theta2, theta3):
    x = (np.cos(theta1)*l1)+(np.cos(theta1+theta2)*l2)+(np.cos(theta1+theta2+theta3)*l3)
    y = (np.sin(theta1)*l1)+(np.sin(theta1+theta2)*l2)+(np.sin(theta1+theta2+theta3)*l3)

    return x, y

# %%
iiitm_data = pd.read_csv('iiitm.csv')
iiitm_predictions = model.predict(iiitm_data.values)
x_predictions, y_predictions = three_link_forward_kinematics(iiitm_predictions[:,0], iiitm_predictions[:,1], iiitm_predictions[:,2])

# %%
# Original
plt.plot(iiitm_data['x'], iiitm_data['y'], 'go')
plt.show()

# Predicted
plt.plot(x_predictions, y_predictions, 'bo')
plt.show()

# Original and Predicted
plt.plot(iiitm_data['x'], iiitm_data['y'], 'go')
plt.plot(x_predictions, y_predictions, 'bo')
plt.show()
